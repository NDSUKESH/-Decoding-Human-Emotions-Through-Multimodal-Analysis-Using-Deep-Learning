# %%
#library
import pandas as pd
import numpy as np 
# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
train=pd.read_csv("/Users/arvinthus/Downloads/S8/train_merged.csv")
dev=pd.read_csv("/Users/arvinthus/Downloads/S8/dev_merged.csv")

# %%
train
# Out:
#                                               Utterance   Emotion  \
# 0     also I was the point person on my companys tr...   neutral
# 1                      You mustve had your hands full.   neutral
# 2                               That I did. That I did.   neutral
# 3         So lets talk a little bit about your duties.   neutral
# 4                                My duties?  All right.  surprise
# ...                                                 ...       ...
# 9580                                         You or me?   neutral
# 9581  I got it. Uh, Joey, women don't have Adam's ap...   neutral
# 9582               You guys are messing with me, right?  surprise
# 9583                                              Yeah.   neutral
# 9584  That was a good one. For a second there, I was...       joy
#
#           file_name                                      text_embedded  \
# 0         dia0_utt0  [-1.31458908e-01 -1.72544960e-02  1.05243176e-...
# 1         dia0_utt1  [-4.21393476e-02  4.15060222e-02  5.01765087e-...
# 2         dia0_utt2  [ 5.02859987e-02 -5.54202916e-03  4.67068925e-...
# 3         dia0_utt3  [ 3.89313884e-03  4.40940224e-02  5.99569939e-...
# 4         dia0_utt4  [-3.44950967e-02  1.93616357e-02  7.62079731e-...
# ...             ...                                                ...
# 9580  dia1038_utt13  [-5.86172082e-02  7.39674866e-02 -8.01084377e-...
# 9581  dia1038_utt14  [ 3.41740735e-02  3.57853919e-02 -2.12731548e-...
# 9582  dia1038_utt15  [ 3.10330987e-02  8.54950678e-03  8.30181912e-...
# 9583  dia1038_utt16  [-1.46411374e-01  5.65296644e-03 -9.10743885e-...
# 9584  dia1038_utt17  [-6.61767945e-02  4.18872088e-02  3.14832246e-...
#
#            filename                                     extracted_data
# 0         dia0_utt0  [[ 1.34087457e-01  6.27370715e-01  4.40108806e...
# 1         dia0_utt1  [[ 1.29256811e-01  6.26780272e-01  4.16521072e...
# 2         dia0_utt2  [[ 1.41352635e-01  4.20076609e-01  5.89790702e...
# 3         dia0_utt3  [[ 1.48058303e-01  3.64203542e-01  2.89357007e...
# 4         dia0_utt4  [[ 1.30692093e-01  3.40013236e-01  3.58041942e...
# ...             ...                                                ...
# 9580  dia1038_utt13  [[ 7.92496928e-02  3.92701566e-01  3.90606403e...
# 9581  dia1038_utt14  [[ 4.91480334e-02  3.59533757e-01  3.33861351e...
# 9582  dia1038_utt15  [[ 7.21214658e-02  3.30627710e-01  2.85190970e...
# 9583  dia1038_utt16  [[ 1.05773926e-01  3.11412364e-01  2.20481411e...
# 9584  dia1038_utt17  [[ 6.87934028e-02  2.44030550e-01  2.05981195e...
#
# [9585 rows x 6 columns]

# %%
train.rename(columns={'extracted_data': 'audio_features'}, inplace=True)
dev.rename(columns={'extracted_data': 'audio_features'}, inplace=True)

# %%
train
# Out:
#                                               Utterance   Emotion  \
# 0     also I was the point person on my companys tr...   neutral
# 1                      You mustve had your hands full.   neutral
# 2                               That I did. That I did.   neutral
# 3         So lets talk a little bit about your duties.   neutral
# 4                                My duties?  All right.  surprise
# ...                                                 ...       ...
# 9580                                         You or me?   neutral
# 9581  [[ 4.91480334e-02  3.59533757e-01  3.33861351e...
# 9582  [[ 7.21214658e-02  3.30627710e-01  2.85190970e...
# 9583  [[ 1.05773926e-01  3.11412364e-01  2.20481411e...
# 9584  [[ 6.87934028e-02  2.44030550e-01  2.05981195e...
#
# [9585 rows x 4 columns]

# %%
dev
# Out:
#                                               Utterance   Emotion  \
# 0        Oh my God, hes lost it. Hes totally lost it.   sadness
# 1                                                 What?  surprise
# 2     Or! Or, we could go to the bank, close our acc...   neutral
# 3                                      Youre a genius!       joy
# 4               Aww, man, now we wont be bank buddies!   sadness
# ...                                                 ...       ...
# 1056                                                No.   sadness
# 1057       What? Oh my God! Im gonna miss you so much!   sadness
# 1058                                Im gonna miss you!   sadness
# 1059                     I mean its the end of an era!   sadness
# 1060                                            I know!   sadness
#
#                                           text_embedded  \
# 0     [ 7.69477896e-03  8.05744752e-02  3.29797901e-...
# 1     [-1.01225428e-01 -1.85939856e-02 -4.19104882e-...
# 2     [-6.23893365e-02  6.11942746e-02 -5.14132008e-...
# 3     [ 4.66335472e-03  7.39181191e-02  3.60610485e-...
# 4     [-1.47925746e-02 -3.13584022e-02 -1.89673230e-...
# ...                                                 ...
# 1056  [-7.26952180e-02  1.45098493e-02  6.78025326e-...
# 1057  [ 2.34280918e-02 -2.82904729e-02  2.82736905e-...
# 1058  [-5.57095222e-02 -7.15075880e-02  6.42618388e-...
# 1059  [ 2.98695527e-02  7.73971602e-02  5.36296740e-...
# 1060  [ 3.69448252e-02  5.69788925e-02 -2.08581183e-...
#
#                                          audio_features
# 0     [[ 1.19247437e-01  3.76063377e-01  3.39651704e...
# 1     [[ 1.11476089e-01  3.62448841e-01  3.49401265e...
# 2     [[ 9.66525608e-02  3.44619930e-01  2.69980401e...
# 3     [[ 1.98189113e-01  4.99972880e-01  4.97676671e...
# 4     [[ 1.11554181e-01  5.61635196e-01  4.66078222e...
# ...                                                 ...
# 1056  [[ 1.74738104e-01  3.38652074e-01  2.90151536e...
# 1057  [[ 3.02812292e-01  3.65345895e-01  3.61546010e...
# 1058  [[ 2.00453272e-01  3.50698590e-01  2.96891421e...
# 1059  [[ 2.13600852e-01  2.26801902e-01  3.21139663e...
# 1060  [[ 1.21765137e-01  3.62470120e-01  2.80552119e...
#
# [1061 rows x 4 columns]

# %%
train['audio_features'] = train['audio_features'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
train['text_embedded'] = train['text_embedded'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
dev['audio_features'] = dev['audio_features'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
dev['text_embedded'] = dev['text_embedded'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
# Out:
# /var/folders/jy/gvnyq1j539912gswm_20zmvh0000gn/T/ipykernel_64258/2628000914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['audio_features'] = train['audio_features'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
# /var/folders/jy/gvnyq1j539912gswm_20zmvh0000gn/T/ipykernel_64258/2628000914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['text_embedded'] = train['text_embedded'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
# /var/folders/jy/gvnyq1j539912gswm_20zmvh0000gn/T/ipykernel_64258/2628000914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev['audio_features'] = dev['audio_features'].apply(lambda x: [float(val) for val in x.strip('[]').split()])
# /var/folders/jy/gvnyq1j539912gswm_20zmvh0000gn/T/ipykernel_64258/2628000914.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dev['text_embedded'] = dev['text_embedded'].apply(lambda x: [float(val) for val in x.strip('[]').split()])

# %%
print(len(train["text_embedded"][0]))
print(len(train["audio_features"][0]))
print(len(dev["text_embedded"][0]))
print(len(dev["audio_features"][0]))
# Out:
# 384
# 155
# 384
# 155

# %%
print(type(train["text_embedded"][0]))
print(type(train["audio_features"][0]))
print(type(dev["text_embedded"][0]))
print(type(dev["audio_features"][0]))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
train
# Out:
#                                               Utterance   Emotion  \
# 0     also I was the point person on my companys tr...   neutral
# 1                      You mustve had your hands full.   neutral
# 2                               That I did. That I did.   neutral
# 3         So lets talk a little bit about your duties.   neutral
# 4                                My duties?  All right.  surprise
# ...                                                 ...       ...
# 9580                                         You or me?   neutral
# 9581  I got it. Uh, Joey, women don't have Adam's ap...   neutral
# 9582               You guys are messing with me, right?  surprise
# 9583                                              Yeah.   neutral
# 9584  That was a good one. For a second there, I was...       joy
#
#                                           text_embedded  \
# 0     [-0.131458908, -0.017254496, 0.0105243176, -0....
# 1     [-0.0421393476, 0.0415060222, 0.0501765087, 0....
# 2     [0.0502859987, -0.00554202916, 0.0467068925, -...
# 3     [0.00389313884, 0.0440940224, 0.0599569939, -0...
# 4     [-0.0344950967, 0.0193616357, 0.0762079731, -0...
# ...                                                 ...
# 9580  [-0.0586172082, 0.0739674866, -0.00801084377, ...
# 9581  [0.0341740735, 0.0357853919, -0.0212731548, 0....
# 9582  [0.0310330987, 0.00854950678, 0.0830181912, -0...
# 9583  [-0.146411374, 0.00565296644, -0.00910743885, ...
# 9584  [-0.0661767945, 0.0418872088, 0.00314832246, -...
#
#                                          audio_features
# 0     [0.134087457, 0.627370715, 0.440108806, 0.2853...
# 1     [0.129256811, 0.626780272, 0.416521072, 0.2926...
# 2     [0.141352635, 0.420076609, 0.589790702, 0.6092...
# 3     [0.148058303, 0.364203542, 0.289357007, 0.3201...
# 4     [0.130692093, 0.340013236, 0.358041942, 0.4327...
# ...                                                 ...
# 9580  [0.0792496928, 0.392701566, 0.390606403, 0.529...
# 9581  [0.0491480334, 0.359533757, 0.333861351, 0.300...
# 9582  [0.0721214658, 0.33062771, 0.28519097, 0.28103...
# 9583  [0.105773926, 0.311412364, 0.220481411, 0.2288...
# 9584  [0.0687934028, 0.24403055, 0.205981195, 0.2024...
#
# [9585 rows x 4 columns]

# %%
dev
# Out:
#                                               Utterance   Emotion  \
# 0        Oh my God, hes lost it. Hes totally lost it.   sadness
# 1                                                 What?  surprise
# 2     Or! Or, we could go to the bank, close our acc...   neutral
# 3                                      Youre a genius!       joy
# 4               Aww, man, now we wont be bank buddies!   sadness
# ...                                                 ...       ...
# 1056                                                No.   sadness
# 1057       What? Oh my God! Im gonna miss you so much!   sadness
# 1058                                Im gonna miss you!   sadness
# 1059                     I mean its the end of an era!   sadness
# 1060                                            I know!   sadness
#
#                                           text_embedded  \
# 0     [0.00769477896, 0.0805744752, 0.0329797901, 0....
# 1     [-0.101225428, -0.0185939856, -0.0419104882, -...
# 2     [-0.0623893365, 0.0611942746, -0.0514132008, 5...
# 3     [0.00466335472, 0.0739181191, 0.0360610485, -0...
# 4     [-0.0147925746, -0.0313584022, -0.018967323, -...
# ...                                                 ...
# 1056  [-0.072695218, 0.0145098493, 0.00678025326, 0....
# 1057  [0.0234280918, -0.0282904729, 0.0282736905, 0....
# 1058  [-0.0557095222, -0.071507588, 0.0642618388, 0....
# 1059  [0.0298695527, 0.0773971602, 0.053629674, -0.0...
# 1060  [0.0369448252, 0.0569788925, -0.0208581183, -0...
#
#                                          audio_features
# 0     [0.119247437, 0.376063377, 0.339651704, 0.3606...
# 1     [0.111476089, 0.362448841, 0.349401265, 0.4622...
# 2     [0.0966525608, 0.34461993, 0.269980401, 0.3028...
# 3     [0.198189113, 0.49997288, 0.497676671, 0.44392...
# 4     [0.111554181, 0.561635196, 0.466078222, 0.2872...
# ...                                                 ...
# 1056  [0.174738104, 0.338652074, 0.290151536, 0.3209...
# 1057  [0.302812292, 0.365345895, 0.36154601, 0.44661...
# 1058  [0.200453272, 0.35069859, 0.296891421, 0.23433...
# 1059  [0.213600852, 0.226801902, 0.321139663, 0.2949...
# 1060  [0.121765137, 0.36247012, 0.280552119, 0.27261...
#
# [1061 rows x 4 columns]

# %%
train['Emotion'].unique()
# Out:
# array(['neutral', 'surprise', 'fear', 'sadness', 'joy', 'disgust',
#        'anger'], dtype=object)

# %%
train.head()
# Out:
#                                            Utterance   Emotion  \
# 0  also I was the point person on my companys tr...   neutral
# 1                   You mustve had your hands full.   neutral
# 2                            That I did. That I did.   neutral
# 3      So lets talk a little bit about your duties.   neutral
# 4                             My duties?  All right.  surprise
#
#                                        text_embedded  \
# 0  [-0.131458908, -0.017254496, 0.0105243176, -0....
# 1  [-0.0421393476, 0.0415060222, 0.0501765087, 0....
# 2  [0.0502859987, -0.00554202916, 0.0467068925, -...
# 3  [0.00389313884, 0.0440940224, 0.0599569939, -0...
# 4  [-0.0344950967, 0.0193616357, 0.0762079731, -0...
#
#                                       audio_features
# 0  [0.134087457, 0.627370715, 0.440108806, 0.2853...
# 1  [0.129256811, 0.626780272, 0.416521072, 0.2926...
# 2  [0.141352635, 0.420076609, 0.589790702, 0.6092...
# 3  [0.148058303, 0.364203542, 0.289357007, 0.3201...
# 4  [0.130692093, 0.340013236, 0.358041942, 0.4327...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
train['Emotion_Encoded'] = label_encoder.fit_transform(train['Emotion'])
# Out:
# /var/folders/jy/gvnyq1j539912gswm_20zmvh0000gn/T/ipykernel_64258/2433085132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Emotion_Encoded'] = label_encoder.fit_transform(train['Emotion'])

# %%
emotion_labels=train[['Emotion','Emotion_Encoded']]

# %%
# Get unique emotions and their encoded labels
unique_emotions = emotion_labels[['Emotion', 'Emotion_Encoded']].drop_duplicates()

# Create a dictionary mapping emotions to their encoded labels
emotion_label_map = dict(zip(unique_emotions['Emotion'], unique_emotions['Emotion_Encoded']))

# Print the emotion label map
print("Emotion Label Map:")
for emotion, label in emotion_label_map.items():
    print(f"{emotion}: {label}")
# Out:
# Emotion Label Map:
# neutral: 4
# surprise: 6
# fear: 2
# sadness: 5
# joy: 3
# disgust: 1
# anger: 0

# %%
train["Emotion"].value_counts()
# Out:
# Emotion
# neutral     4510
# joy         1659
# surprise    1149
# anger       1064
# sadness      673
# disgust      266
# fear         264
# Name: count, dtype: int64

# %%
train = train[(train['Emotion'] != 'fear') & (train['Emotion'] != 'disgust')]

# %%
train["Emotion"].value_counts()
# Out:
# Emotion
# neutral     4510
# joy         1659
# surprise    1149
# anger       1064
# sadness      673
# Name: count, dtype: int64

# %%
from keras.layers import Input, LSTM, Bidirectional, Concatenate, Dense, Dropout, Flatten, Attention, Conv1D, MaxPooling1D
from keras.models import Model

def create_complex_multimodal_model(input_shape_text, input_shape_audio, num_classes):
    # Text input
    text_input = Input(shape=input_shape_text, name='text_input')
    # Audio input
    audio_input = Input(shape=input_shape_audio, name='audio_input')

    # Text processing layers
    text_lstm1 = Bidirectional(LSTM(128, return_sequences=True))(text_input)
    text_lstm2 = Bidirectional(LSTM(64, return_sequences=True))(text_lstm1)
    text_attention = Attention()([text_lstm2, text_lstm2])
    text_dropout = Dropout(0.5)(text_attention)
    text_flatten = Flatten()(text_dropout)

    # Audio processing layers
    audio_conv1 = Conv1D(64, 3, activation='relu')(audio_input)
    audio_pool1 = MaxPooling1D(pool_size=2)(audio_conv1)
    audio_conv2 = Conv1D(128, 3, activation='relu')(audio_pool1)
    audio_pool2 = MaxPooling1D(pool_size=2)(audio_conv2)
    audio_lstm1 = Bidirectional(LSTM(64, return_sequences=True))(audio_pool2)
    audio_lstm2 = Bidirectional(LSTM(32, return_sequences=True))(audio_lstm1)
    audio_attention = Attention()([audio_lstm2, audio_lstm2])
    audio_dropout = Dropout(0.5)(audio_attention)
    audio_flatten = Flatten()(audio_dropout)

    # Concatenate text and audio features
    merged_features = Concatenate()([text_flatten, audio_flatten])

    # Fully connected layers
    fc1 = Dense(512, activation='relu')(merged_features)
    fc_dropout = Dropout(0.5)(fc1)

    # Output layer
    output = Dense(num_classes, activation='softmax')(fc_dropout)

    # Create model
    model = Model(inputs=[text_input, audio_input], outputs=output)

    return model

# %%
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from keras.utils import to_categorical

# Split the data into train and validation sets
train_df, val_df = train_test_split(train, test_size=0.2, random_state=42)

# Prepare text data
text_data_train = np.array([np.array(embedded) for embedded in train_df['text_embedded'].values])
text_data_train = np.expand_dims(text_data_train, axis=-1)  # Add third dimension
text_data_val = np.array([np.array(embedded) for embedded in val_df['text_embedded'].values])
text_data_val = np.expand_dims(text_data_val, axis=-1)  # Add third dimension

# Prepare audio data
audio_data_train = np.array([np.array(features) for features in train_df['audio_features'].values])
audio_data_train = np.expand_dims(audio_data_train, axis=-1)  # Add third dimension
audio_data_val = np.array([np.array(features) for features in val_df['audio_features'].values])
audio_data_val = np.expand_dims(audio_data_val, axis=-1)  # Add third dimension

# One-hot encode emotion labels
labels_train = to_categorical(train_df['Emotion_Encoded'])
labels_val = to_categorical(val_df['Emotion_Encoded'])

# Create the model
model = create_complex_multimodal_model(input_shape_text=text_data_train.shape[1:],
                                        input_shape_audio=audio_data_train.shape[1:],
                                        num_classes=labels_train.shape[1])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define early stopping to prevent overfitting
# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit([text_data_train, audio_data_train], labels_train,
                    validation_data=([text_data_val, audio_data_val], labels_val),
                    epochs=80, batch_size=32)

# Evaluate the model on the validation set
# val_loss, val_accuracy = model.evaluate([text_data_val, audio_data_val], labels_val)
# print("Validation Loss:", val_loss)
# print("Validation Accuracy:", val_accuracy)
# Out:
# Epoch 1/80
# W0000 00:00:1711049313.008014       1 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" frequency: 2400 num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# W0000 00:00:1711049313.008346       1 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" frequency: 2400 num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 227/227 [==============================] - ETA: 0s - loss: 1.4235 - accuracy: 0.4891
# W0000 00:00:1711049401.969689       1 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" frequency: 2400 num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# W0000 00:00:1711049401.969834       1 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" frequency: 2400 num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 227/227 [==============================] - 98s 420ms/step - loss: 1.4235 - accuracy: 0.4891 - val_loss: 1.3413 - val_accuracy: 0.5064
# Epoch 2/80
# 227/227 [==============================] - 90s 398ms/step - loss: 1.3802 - accuracy: 0.4954 - val_loss: 1.3408 - val_accuracy: 0.5047
# Epoch 3/80
# 227/227 [==============================] - 92s 405ms/step - loss: 1.3768 - accuracy: 0.4930 - val_loss: 1.3503 - val_accuracy: 0.5047
# Epoch 63/80
# 227/227 [==============================] - 120s 528ms/step - loss: 0.2289 - accuracy: 0.9195 - val_loss: 5.0819 - val_accuracy: 0.3727
# Epoch 64/80
# 227/227 [==============================] - 118s 521ms/step - loss: 0.1664 - accuracy: 0.9405 - val_loss: 5.2584 - val_accuracy: 0.3716
# Epoch 65/80
# 227/227 [==============================] - 121s 532ms/step - loss: 0.1684 - accuracy: 0.9416 - val_loss: 5.1389 - val_accuracy: 0.3799
# Epoch 66/80
# 227/227 [==============================] - 121s 535ms/step - loss: 0.1838 - accuracy: 0.9375 - val_loss: 4.9335 - val_accuracy: 0.3689
# Epoch 67/80
# 227/227 [==============================] - 124s 545ms/step - loss: 0.1757 - accuracy: 0.9380 - val_loss: 5.3701 - val_accuracy: 0.3727
# Epoch 68/80
# 227/227 [==============================] - 124s 546ms/step - loss: 0.1502 - accuracy: 0.9500 - val_loss: 5.8530 - val_accuracy: 0.3606
# Epoch 69/80
# 227/227 [==============================] - 122s 539ms/step - loss: 0.1736 - accuracy: 0.9398 - val_loss: 5.6403 - val_accuracy: 0.3705
# Epoch 70/80
# 227/227 [==============================] - 122s 538ms/step - loss: 0.2180 - accuracy: 0.9249 - val_loss: 4.9002 - val_accuracy: 0.3528
# Epoch 71/80
# 227/227 [==============================] - 124s 547ms/step - loss: 0.1810 - accuracy: 0.9362 - val_loss: 5.7654 - val_accuracy: 0.3539
# Epoch 72/80
# 227/227 [==============================] - 121s 533ms/step - loss: 0.1345 - accuracy: 0.9542 - val_loss: 6.2687 - val_accuracy: 0.3832
# Epoch 73/80
# 227/227 [==============================] - 121s 533ms/step - loss: 0.1786 - accuracy: 0.9388 - val_loss: 5.2954 - val_accuracy: 0.4009
# Epoch 74/80
# 227/227 [==============================] - 122s 538ms/step - loss: 0.1647 - accuracy: 0.9445 - val_loss: 5.3849 - val_accuracy: 0.3793
# Epoch 75/80
# 227/227 [==============================] - 121s 534ms/step - loss: 0.1216 - accuracy: 0.9583 - val_loss: 5.7744 - val_accuracy: 0.4014
# Epoch 76/80
# 227/227 [==============================] - 121s 534ms/step - loss: 0.1514 - accuracy: 0.9470 - val_loss: 6.1698 - val_accuracy: 0.3920
# Epoch 77/80
# 227/227 [==============================] - 119s 523ms/step - loss: 0.1710 - accuracy: 0.9449 - val_loss: 5.4756 - val_accuracy: 0.3821
# Epoch 78/80
# 227/227 [==============================] - 118s 521ms/step - loss: 0.1265 - accuracy: 0.9575 - val_loss: 5.5169 - val_accuracy: 0.3805
# Epoch 79/80
# 227/227 [==============================] - 120s 528ms/step - loss: 0.1315 - accuracy: 0.9569 - val_loss: 5.5708 - val_accuracy: 0.3733
# Epoch 80/80
# 227/227 [==============================] - 122s 539ms/step - loss: 0.1231 - accuracy: 0.9558 - val_loss: 5.1568 - val_accuracy: 0.3567

# %%
import pickle

with open('multimodal_model_v5.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
model.save('multimodal_model.h5')
# Out:
# /Users/arvinthus/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
